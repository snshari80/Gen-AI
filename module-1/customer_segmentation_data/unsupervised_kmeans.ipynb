# %% [markdown]
# K Means

# %%
import pandas as pd
print("Pd version imported:", pd.__version__)

df = pd.read_csv('customer_segmentation_data.csv')
# df.head()

from sklearn.cluster import KMeans
print("KMeans imported successfully.")

X = df[['Annual_Income', 'Spending_Score']]
# print(X.head())

model = KMeans(n_clusters=5, random_state=42)
# print("KMeans model created successfully.")


df['Cluster'] = model.fit_predict(X)
print(df.head())
# Out:
# Pd version imported: 3.0.1
# KMeans imported successfully.
#    CustomerID  Age  Annual_Income  Spending_Score  Cluster
# 0           1   56          28392              19        3
# 1           2   46          50535              20        1
# 2           3   32          98603              96        2
# 3           4   25          72256              71        0
# 4           5   38          55222              52        1
