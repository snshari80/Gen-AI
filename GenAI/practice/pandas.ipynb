# %% [markdown]
# Pandas

# %%
import pandas as pd

# df = pd.DataFrame({
#     'A': [1, 2, 3],
#     'B': [4, 5, 6],
#     'C': [7, 8, 9]
# })

df = pd.read_csv('C:\\Users\\snsha\\Downloads\\people-100.csv')
# print(df)

ages = df[df['Sex'] == 'Male']
email = df[df['Email'].str.endswith('.com')]
# print(email)

particular_age = df['Date of birth']
converted_age = particular_age.apply(lambda x: int(x.split('-')[0]))
check_age = converted_age[converted_age < 1990]
# print(check_age)

total_age = converted_age.mean()
# print(total_age)

full_Name = df.groupby('First Name')
size = full_Name.size()
print(size)
# Out:
# First Name
# Alfred      1
# Alison      1
# Alvin       1
# Andrew      1
# Becky       1
#            ..
# Veronica    1
# Wesley      1
# Willie      1
# Xavier      1
# Yesenia     1
# Length: 94, dtype: int64
